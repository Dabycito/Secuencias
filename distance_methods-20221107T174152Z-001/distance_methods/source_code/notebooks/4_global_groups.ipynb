# %%
import os

import pandas as pd

# %%
dataset = {
    0 : "absorption",
    1 : "enantioselectivity",
    2 : "localization",
    3 : "T50"
}
method = {
    0:"FFT",
    1:"NLP",
    2:"Properties"
}
bioembedding = {
    0:"bepler",
    1:"esm",
    2:"fasttext",
    3:"plus_rnn",
    4:"prottrans"
}
distances = {
    1 : "Euclidean",
    2 : "Braycurtis",
    3 : "Canberra",
    4 : "Chebyshev",
    5 : "Cityblock",
    6 : "Correlation",
    7 : "Cosine",
    8 : "Minkowski",
    9 : "Hamming"
}
absorption_parent = {
    0 : "sequence_40826",
}
localization_parent = {
    0 : "sequence_51016",
    1 : "sequence_51170",
    2 : "sequence_32130",
}
enantio_parent = {
    0 : "sequence_47787",
}
t50_parent = {
    0 : "sequence_53082",
    1 : "sequence_19402",
    2 : "sequence_20054",
}

# %%
for a in range (0,4): #Se elije el dataset
    for b in range(0,3): #Se elije el metodo de representacion numerica
        if b==1: #Si es NLP entra a este if
            for c in range(0,5): #Cual de los 5 metodos de PLM
                for d in range(1,10): #Se elije la distancia
                    df_profiles = pd.read_csv("../../results_demo/"+dataset[a]+"/"+method[b]+"/"+bioembedding[c]+"/"+distances[d]+"/generated_profiles.csv")
                    df_distances = pd.read_csv("../../results_demo/"+dataset[a]+"/"+method[b]+"/"+bioembedding[c]+"/"+distances[d]+"/distance_estimator.csv")
                    profiles = df_profiles.profile.unique()
                    for f in range(0,len(profiles)): #para entrar a cada perfil
                        df_f = (df_profiles["profile"] == profiles[f])
                        clust_aux = df_profiles[df_f]
                        Cluster = pd.DataFrame()
                        if a == 0: #Absorption
                            for g in range(0,len(clust_aux.index)): #Esto para elegir la o las nativas
                                df_filter = df_distances[(df_distances.id_seq1==absorption_parent[0]) & (df_distances.id_seq2 == clust_aux.iloc[g][0])]
                                Cluster = pd.concat([Cluster,df_filter])
                            try:
                                os.mkdir("../../results_demo/"+dataset[a]+"/NLP/"+bioembedding[c]+"/"+distances[d]+"/clusters")
                            except:
                                print("a")
                            Cluster.to_csv("../../results_demo/"+dataset[a]+"/NLP/"+bioembedding[c]+"/"+distances[d]+"/clusters/cluster"+profiles[f]+".csv")
                        if a == 1: #Enantioselectivity
                            for g in range(0,len(clust_aux.index)): #Esto para elegir la o las nativas
                                df_filter = df_distances[(df_distances.id_seq1==enantio_parent[0]) & (df_distances.id_seq2 == clust_aux.iloc[g][0])]
                                Cluster = pd.concat([Cluster,df_filter])
                            try:
                                os.mkdir("../../results_demo/"+dataset[a]+"/NLP/"+bioembedding[c]+"/"+distances[d]+"/clusters")
                            except:
                                print("a")
                            Cluster.to_csv("../../results_demo/"+dataset[a]+"/NLP/"+bioembedding[c]+"/"+distances[d]+"/clusters/cluster"+profiles[f]+".csv")
                        if a == 2: #Localization
                            for parent in range(0,3):
                                for g in range(0,len(clust_aux.index)): #Esto para elegir la o las nativas
                                    df_filter = df_distances[(df_distances.id_seq1==localization_parent[parent]) & (df_distances.id_seq2 == clust_aux.iloc[g][0])]
                                    Cluster = pd.concat([Cluster,df_filter])
                                try:
                                    os.mkdir("../../results_demo/"+dataset[a]+"/NLP/"+bioembedding[c]+"/"+distances[d]+"/clusters")
                                except:
                                    print("a")
                                Cluster.to_csv("../../results_demo/"+dataset[a]+"/NLP/"+bioembedding[c]+"/"+distances[d]+"/clusters/cluster"+profiles[f]+"-parent_"+parent+".csv")
                        if a == 3: #T50
                            for parent in range(0,3):
                                for g in range(0,len(clust_aux.index)): #Esto para elegir la o las nativas
                                    df_filter = df_distances[(df_distances.id_seq1==t50_parent[parent]) & (df_distances.id_seq2 == clust_aux.iloc[g][0])]
                                    Cluster = pd.concat([Cluster,df_filter])
                                try:
                                    os.mkdir("../../results_demo/"+dataset[a]+"/NLP/"+bioembedding[c]+"/"+distances[d]+"/clusters")
                                except:
                                    print("a")
                                Cluster.to_csv("../../results_demo/"+dataset[a]+"/NLP/"+bioembedding[c]+"/"+distances[d]+"/clusters/cluster"+profiles[f]+"-parent_"+parent+".csv")
        if b == 0:
            for c in range(0,8):
                for d in range(1,10): #Se elije la distancia
                    df_profiles = pd.read_csv("../../results_demo/"+dataset[a]+"/"+method[b]+"/Group_"+str(c)+"/"+distances[d]+"/generated_profiles.csv")
                    df_distances = pd.read_csv("../../results_demo/"+dataset[a]+"/"+method[b]+"/Group_"+str(c)+"/"+distances[d]+"/distance_estimator.csv")
                    profiles = df_profiles.profile.unique()
                    for f in range(0,len(profiles)): #para entrar a cada perfil
                        df_f = (df_profiles["profile"] == profiles[f])
                        clust_aux = df_profiles[df_f]
                        Cluster = pd.DataFrame()
                        if a == 0: #Absorption
                            for g in range(0,len(clust_aux.index)): #Esto para elegir la o las nativas
                                df_filter = df_distances[(df_distances.id_seq1==absorption_parent[0]) & (df_distances.id_seq2 == clust_aux.iloc[g][0])]
                                Cluster = pd.concat([Cluster,df_filter])
                            try:
                                os.mkdir("../../results_demo/"+dataset[a]+"/"+method[b]+"/Group_"+str(c)+"/"+distances[d]+"/clusters")
                            except:
                                print("a")
                            Cluster.to_csv("../../results_demo/"+dataset[a]+"/"+method[b]+"/Group_"+str(c)+"/"+distances[d]+"/clusters/cluster"+profiles[f]+".csv")
                        if a == 1: #Enantioselectivity
                            for g in range(0,len(clust_aux.index)): #Esto para elegir la o las nativas
                                df_filter = df_distances[(df_distances.id_seq1==enantio_parent[0]) & (df_distances.id_seq2 == clust_aux.iloc[g][0])]
                                Cluster = pd.concat([Cluster,df_filter])
                            try:
                                os.mkdir("../../results_demo/"+dataset[a]+"/"+method[b]+"/Group_"+str(c)+"/"+distances[d]+"/clusters")
                            except:
                                print("a")
                            Cluster.to_csv("../../results_demo/"+dataset[a]+"/"+method[b]+"/Group_"+str(c)+"/"+distances[d]+"/clusters/cluster"+profiles[f]+".csv")
                        if a == 2: #Localization
                            for parent in range(0,3):
                                for g in range(0,len(clust_aux.index)): #Esto para elegir la o las nativas
                                    df_filter = df_distances[(df_distances.id_seq1==localization_parent[parent]) & (df_distances.id_seq2 == clust_aux.iloc[g][0])]
                                    Cluster = pd.concat([Cluster,df_filter])
                                try:
                                    os.mkdir("../../results_demo/"+dataset[a]+"/"+method[b]+"/Group_"+str(c)+"/"+distances[d]+"/clusters")
                                except:
                                    print("a")
                                Cluster.to_csv("../../results_demo/"+dataset[a]+"/"+method[b]+"/Group_"+str(c)+"/"+distances[d]+"/clusters/cluster"+profiles[f]+"-parent_"+parent+".csv")
                        if a == 3: #T50
                            for parent in range(0,3):
                                for g in range(0,len(clust_aux.index)): #Esto para elegir la o las nativas
                                    df_filter = df_distances[(df_distances.id_seq1==t50_parent[parent]) & (df_distances.id_seq2 == clust_aux.iloc[g][0])]
                                    Cluster = pd.concat([Cluster,df_filter])
                                try:
                                    os.mkdir("../../results_demo/"+dataset[a]+"/"+method[b]+"/Group_"+str(c)+"/"+distances[d]+"/clusters")
                                except:
                                    print("a")
                                Cluster.to_csv("../../results_demo/"+dataset[a]+"/"+method[b]+"/Group_"+str(c)+"/"+distances[d]+"/clusters/cluster"+profiles[f]+"-parent_"+parent+".csv")
        if b == 2:
            for c in range(0,8):
                for d in range(1,10): #Se elije la distancia
                    df_profiles = pd.read_csv("../../results_demo/"+dataset[a]+"/"+method[b]+"/Group_"+str(c)+"/"+distances[d]+"/generated_profiles.csv")
                    df_distances = pd.read_csv("../../results_demo/"+dataset[a]+"/"+method[b]+"/Group_"+str(c)+"/"+distances[d]+"/distance_estimator.csv")
                    profiles = df_profiles.profile.unique()
                    for f in range(0,len(profiles)): #para entrar a cada perfil
                        df_f = (df_profiles["profile"] == profiles[f])
                        clust_aux = df_profiles[df_f]
                        Cluster = pd.DataFrame()
                        if a == 0: #Absorption
                            for g in range(0,len(clust_aux.index)): #Esto para elegir la o las nativas
                                df_filter = df_distances[(df_distances.id_seq1==absorption_parent[0]) & (df_distances.id_seq2 == clust_aux.iloc[g][0])]
                                Cluster = pd.concat([Cluster,df_filter])
                            try:
                                os.mkdir("../../results_demo/"+dataset[a]+"/"+method[b]+"/Group_"+str(c)+"/"+distances[d]+"/clusters")
                            except:
                                print("a")
                            Cluster.to_csv("../../results_demo/"+dataset[a]+"/"+method[b]+"/Group_"+str(c)+"/"+distances[d]+"/clusters/cluster"+profiles[f]+".csv")
                        if a == 1: #Enantioselectivity
                            for g in range(0,len(clust_aux.index)): #Esto para elegir la o las nativas
                                df_filter = df_distances[(df_distances.id_seq1==enantio_parent[0]) & (df_distances.id_seq2 == clust_aux.iloc[g][0])]
                                Cluster = pd.concat([Cluster,df_filter])
                            try:
                                os.mkdir("../../results_demo/"+dataset[a]+"/"+method[b]+"/Group_"+str(c)+"/"+distances[d]+"/clusters")
                            except:
                                print("a")
                            Cluster.to_csv("../../results_demo/"+dataset[a]+"/"+method[b]+"/Group_"+str(c)+"/"+distances[d]+"/clusters/cluster"+profiles[f]+".csv")
                        if a == 2: #Localization
                            for parent in range(0,3):
                                for g in range(0,len(clust_aux.index)): #Esto para elegir la o las nativas
                                    df_filter = df_distances[(df_distances.id_seq1==localization_parent[parent]) & (df_distances.id_seq2 == clust_aux.iloc[g][0])]
                                    Cluster = pd.concat([Cluster,df_filter])
                                try:
                                    os.mkdir("../../results_demo/"+dataset[a]+"/"+method[b]+"/Group_"+str(c)+"/"+distances[d]+"/clusters")
                                except:
                                    print("a")
                                Cluster.to_csv("../../results_demo/"+dataset[a]+"/"+method[b]+"/Group_"+str(c)+"/"+distances[d]+"/clusters/cluster"+profiles[f]+"-parent_"+parent+".csv")
                        if a == 3: #T50
                            for parent in range(0,3):
                                for g in range(0,len(clust_aux.index)): #Esto para elegir la o las nativas
                                    df_filter = df_distances[(df_distances.id_seq1==t50_parent[parent]) & (df_distances.id_seq2 == clust_aux.iloc[g][0])]
                                    Cluster = pd.concat([Cluster,df_filter])
                                try:
                                    os.mkdir("../../results_demo/"+dataset[a]+"/"+method[b]+"/Group_"+str(c)+"/"+distances[d]+"/clusters")
                                except:
                                    print("a")
                                Cluster.to_csv("../../results_demo/"+dataset[a]+"/"+method[b]+"/Group_"+str(c)+"/"+distances[d]+"/clusters/cluster"+profiles[f]+"-parent_"+parent+".csv")
# Out:
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In [6], line 21
#      19     except:
#      20         print("a")
# ---> 21     Cluster.to_csv("../../results_demo/"+dataset[a]+"/NLP/"+bioembedding[c]+"/"+distances[d]+"/clusters/cluster"+profiles[f]+".csv")
#      22 if a == 1: #Enantioselectivity
#      23     for g in range(0,len(clust_aux.index)): #Esto para elegir la o las nativas
#
# File ~/.local/lib/python3.10/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/generic.py:3720, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3709 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3711 formatter = DataFrameFormatter(
#    3712     frame=df,
#    3713     header=header,
#    (...)
#    3717     decimal=decimal,
#    3718 )
# -> 3720 return DataFrameRenderer(formatter).to_csv(
#    3721     path_or_buf,
#    3722     lineterminator=lineterminator,
#    3723     sep=sep,
#    3724     encoding=encoding,
#    3725     errors=errors,
#    3726     compression=compression,
#    3727     quoting=quoting,
#    3728     columns=columns,
#    3729     index_label=index_label,
#    3730     mode=mode,
#    3731     chunksize=chunksize,
#    3732     quotechar=quotechar,
#    3733     date_format=date_format,
#    3734     doublequote=doublequote,
#    3735     escapechar=escapechar,
#    3736     storage_options=storage_options,
#    3737 )
#
# File ~/.local/lib/python3.10/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/pandas/io/formats/format.py:1189, in DataFrameRenderer.to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1168     created_buffer = False
#    1170 csv_formatter = CSVFormatter(
#    1171     path_or_buf=path_or_buf,
#    1172     lineterminator=lineterminator,
#    (...)
#    1187     formatter=self.fmt,
#    1188 )
# -> 1189 csv_formatter.save()
#    1191 if created_buffer:
#    1192     assert isinstance(path_or_buf, StringIO)
#
# File ~/.local/lib/python3.10/site-packages/pandas/io/formats/csvs.py:241, in CSVFormatter.save(self)
#     237 """
#     238 Create the writer & save.
#     239 """
#     240 # apply compression and byte/text conversion
# --> 241 with get_handle(
#     242     self.filepath_or_buffer,
#     243     self.mode,
#     244     encoding=self.encoding,
#     245     errors=self.errors,
#     246     compression=self.compression,
#     247     storage_options=self.storage_options,
#     248 ) as handles:
#     249
#     250     # Note: self.encoding is irrelevant here
#     251     self.writer = csvlib.writer(
#     252         handles.handle,
#     253         lineterminator=self.lineterminator,
#    (...)
#     258         quotechar=self.quotechar,
#     259     )
#     261     self._save()
#
# File ~/.local/lib/python3.10/site-packages/pandas/io/common.py:734, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     732 # Only for write methods
#     733 if "r" not in mode and is_path:
# --> 734     check_parent_directory(str(handle))
#     736 if compression:
#     737     if compression != "zstd":
#     738         # compression libraries do not like an explicit text-mode
#
# File ~/.local/lib/python3.10/site-packages/pandas/io/common.py:597, in check_parent_directory(path)
#     595 parent = Path(path).parent
#     596 if not parent.is_dir():
# --> 597     raise OSError(rf"Cannot save file into a non-existent directory: '{parent}'")
#
# OSError: Cannot save file into a non-existent directory: '../../results_demo/absorption/NLP/prottrans/Euclidean/clusters'
